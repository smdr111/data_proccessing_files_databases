# %% [markdown]
# <a href="https://colab.research.google.com/github/smdr111/data_proccessing_files_databases/blob/main/issues1_data_proccessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/h4PPC71.png)
# #**10-modul. Maʼlumotlarga ishlov berish. Fayllar va maʼlumotlar ombori**
# #10.5. Fayldan oʻqish va unga yozish. HDF5
# **Bu vazifalarni bajargach, CSV, Excel va HDF5 formatlarida fayllarni oʻqish hamda saqlash, yaʼni data processing (ma’lumotlarga ishlov berish) koʻnikmasini oʻzlashtirasiz.**

# %% [markdown]
# #1-topshiriq
#
#
# 1.    Quyidagi link orqali maʼlumotlarni Pandas dataframeʼiga yuklab oling.
#
#   *   https://raw.githubusercontent.com/alishermutalov/praktikum-datasets/refs/heads/praktikum/data_date.csv
#
#
#
# 2.   Yuklab olingan maʼlumotlarni `aqi.csv` fayliga saqlang.
#
# 3. Saqlab olingan `aqi.csv` faylining oxirgi 5 ta qatorini oʻqing.
#
# Eslatma: fayl nomini `aqi.csv` deb saqlaganimizning sababi AQI – Air Quality Index, yaʼni havo sifati indeksi deganidir. Bizning maʼlumotlarimizda davlatlarning havo sifati haqidagi maʼlumotlar saqlangan!

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/alishermutalov/praktikum-datasets/refs/heads/praktikum/data_date.csv")
#javobni shu yerda yozing.
df.to_csv('aqi.csv')

# %%
pd.read_csv('aqi.csv').tail()
# Out:
#        Unnamed: 0        Date                   Country    Status  AQI Value
# 18116       18116  2025-03-06  United States of America  Moderate         82
# 18117       18117  2025-03-06                Uzbekistan      Good         17
# 18118       18118  2025-03-06                   Vatican  Moderate         65
# 18119       18119  2025-03-06                 Venezuela      Good         11
# 18120       18120  2025-03-06                   Vietnam  Moderate         64

# %% [markdown]
# #2-topshiriq
# 1. Saqlab olingan `aqi.csv` faylidagi maʼlumotlarning faqat 2024-yilga tegishlisini excel faylga `aqi_2024.xlsx` koʻrinishida saqlab oling.
# 2. Saqlab olingan `aqi_2024.xlsx` faylidan Oʻzbekistonga tegishli maʼlumotni (qatorlarni) oʻqing.

# %%
year=df.Date.str.split('-',expand=True)
year
# Out:
#           0   1   2
# 0      2022  07  21
# 1      2022  07  21
# 2      2022  07  21
# 3      2022  07  21
# 4      2022  07  21
# ...     ...  ..  ..
# 18116  2025  03  06
# 18117  2025  03  06
# 18118  2025  03  06
# 18119  2025  03  06
# 18120  2025  03  06
#
# [18121 rows x 3 columns]

# %%
year.columns=['Year','Month','Date']
year
# Out:
#        Year Month Date
# 0      2022    07   21
# 1      2022    07   21
# 2      2022    07   21
# 3      2022    07   21
# 4      2022    07   21
# ...     ...   ...  ...
# 18116  2025    03   06
# 18117  2025    03   06
# 18118  2025    03   06
# 18119  2025    03   06
# 18120  2025    03   06
#
# [18121 rows x 3 columns]

# %%
df=df.drop('Date',axis=1).join(year)

# %%
obj=df[df.Year=='2024']

# %%
obj.to_excel('aqi_2024.xlsx')

# %%
uzb=pd.read_excel('aqi_2024.xlsx')

# %%
# 3     Angola  Unhealthy for Sensitive Groups        113  2022    07   21
# 4  Argentina                        Moderate         63  2022    07   21

# %%
#javobni shu yerda yozing.
aqi_2022=df[df.Year=='2022']
aqi_2023=df[df.Year=='2023']
aqi_2024=df[df.Year=='2024']
aqi_2025=df[df.Year=='2025']

# %%
aqi_2022.to_csv('aqi_2022.csv')
aqi_2023.to_csv('aqi_2023.csv')
aqi_2024.to_csv('aqi_2024.csv')
aqi_2025.to_csv('aqi_2025.csv')

# %% [markdown]
# #4-topshiriq
# 1. Saqlab olingan `aqi_2022.csv`, `aqi_2023.csv`, `aqi_2024.csv`, `aqi_2025.csv`  fayllarini HDF5 formatida saqlang. Fayl nomini `aqi.h5` deb nomlang. Kalit (key) sifatida fayllarning yillarini bering. Misol uchun, key=2025.

# %%
#javobni shu yerda yozing.
objhdf=pd.HDFStore('aqi.h5')

# %%
objhdf.put('2022',aqi_2022)
# Out:
# /usr/local/lib/python3.12/dist-packages/tables/path.py:146: NaturalNameWarning: object name is not a valid Python identifier: '2022'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)

# %%
objhdf.put('2023',aqi_2023)
objhdf.put('2024',aqi_2024)
objhdf.put('2025',aqi_2025)
# Out:
# /usr/local/lib/python3.12/dist-packages/tables/path.py:146: NaturalNameWarning: object name is not a valid Python identifier: '2023'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /usr/local/lib/python3.12/dist-packages/tables/path.py:146: NaturalNameWarning: object name is not a valid Python identifier: '2024'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /usr/local/lib/python3.12/dist-packages/tables/path.py:146: NaturalNameWarning: object name is not a valid Python identifier: '2025'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)

# %%
objhdf['2022']
# Out:
#          Country                          Status  AQI Value  Year Month Date
# 0        Albania                            Good         14  2022    07   21
# 1        Algeria                        Moderate         65  2022    07   21
# 2        Andorra                        Moderate         55  2022    07   21
# 3         Angola  Unhealthy for Sensitive Groups        113  2022    07   21
# 4      Argentina                        Moderate         63  2022    07   21
# ...          ...                             ...        ...   ...   ...  ...
# 9989  Uzbekistan                        Moderate         66  2022    09   22
# 9990     Vatican                            Good         30  2022    09   22
# 9991   Venezuela                            Good         20  2022    09   22
# 9992     Vietnam                        Moderate         76  2022    09   22
# 9993      Zambia                       Unhealthy        161  2022    09   22
#
# [9994 rows x 6 columns]

# %%
objhdf.close()

# %% [markdown]
# #5-topshiriq
# 1. `aqi.h5` faylidan maʼlumotlarni oʻqing va 2025-yilga tegishli maʼlumotlarni yangi dataframeʼga saqlang.
# 2. `aqi.h5` faylida 2025-yilning qaysi oylari uchun maʼlumotlar bor? Shu oylar roʻyxatini ekranga chiqaring!

# %%
#javobni shu yerda yozing.
h5=pd.read_hdf('aqi.h5',key='2025')
h5.Month.value_counts().index
# Out:
# Index(['01', '02', '03'], dtype='object', name='Month')
